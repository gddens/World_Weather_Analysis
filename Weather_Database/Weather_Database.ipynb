# %%
#Import the dependencies.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | sinnamary
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | wamba
# Processing Record 6 of Set 1 | egvekinot
# Processing Record 7 of Set 1 | essen
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | plettenberg bay
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | monywa
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | kutina
# Processing Record 16 of Set 1 | tirano
# Processing Record 17 of Set 1 | salalah
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | berezovyy
# Processing Record 20 of Set 1 | amarante do maranhao
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | karratha
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | parthenay
# Processing Record 27 of Set 1 | nova vicosa
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | bantry
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | adrar
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | oxford
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | palmer
# Processing Record 43 of Set 1 | pallasovka
# Processing Record 44 of Set 1 | boda
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | cabedelo
# Processing Record 47 of Set 1 | maralal
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | pacifica
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | nabire
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | harlingen
# Processing Record 12 of Set 2 | oranjestad
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | nchelenge
# Processing Record 15 of Set 2 | vasterhaninge
# Processing Record 16 of Set 2 | batagay
# Processing Record 17 of Set 2 | stamsund
# City not found. Skipping...
# Processing Record 18 of Set 2 | constitucion
# Processing Record 19 of Set 2 | ameca
# Processing Record 20 of Set 2 | independence
# Processing Record 21 of Set 2 | hilton head island
# Processing Record 22 of Set 2 | dagana
# Processing Record 23 of Set 2 | kamenka
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | genhe
# Processing Record 27 of Set 2 | verkhoshizhemye
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | meadow lake
# Processing Record 30 of Set 2 | nishihara
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | sao joao da barra
# Processing Record 34 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | taltal
# Processing Record 36 of Set 2 | kautokeino
# Processing Record 37 of Set 2 | kutum
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | wenatchee
# Processing Record 41 of Set 2 | ustka
# Processing Record 42 of Set 2 | doctor juan leon mallorquin
# Processing Record 43 of Set 2 | aquiraz
# Processing Record 44 of Set 2 | san quintin
# Processing Record 45 of Set 2 | ust-kulom
# Processing Record 46 of Set 2 | carutapera
# Processing Record 47 of Set 2 | mount isa
# Processing Record 48 of Set 2 | biskamzha
# Processing Record 49 of Set 2 | cabacao
# Processing Record 50 of Set 2 | itoman
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | sumbe
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | balakhta
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | wangou
# Processing Record 11 of Set 3 | elliot
# Processing Record 12 of Set 3 | jumla
# Processing Record 13 of Set 3 | richards bay
# Processing Record 14 of Set 3 | poronaysk
# Processing Record 15 of Set 3 | galle
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | malpe
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | pingliang
# Processing Record 23 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 3 | xuddur
# Processing Record 25 of Set 3 | banda aceh
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | yerbogachen
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | ankazoabo
# Processing Record 33 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 3 | turukhansk
# Processing Record 35 of Set 3 | tongsa
# City not found. Skipping...
# Processing Record 36 of Set 3 | comodoro rivadavia
# Processing Record 37 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | khorixas
# Processing Record 40 of Set 3 | san pedro de cajas
# Processing Record 41 of Set 3 | maketu
# Processing Record 42 of Set 3 | sotouboua
# Processing Record 43 of Set 3 | chifeng
# Processing Record 44 of Set 3 | iqaluit
# Processing Record 45 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 3 | luang prabang
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | necochea
# Processing Record 49 of Set 3 | shenjiamen
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | sept-iles
# Processing Record 2 of Set 4 | asfi
# Processing Record 3 of Set 4 | lincoln
# Processing Record 4 of Set 4 | vostok
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | bengkulu
# Processing Record 8 of Set 4 | artyom
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | marrakesh
# Processing Record 11 of Set 4 | guisa
# Processing Record 12 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 4 | omutinskoye
# City not found. Skipping...
# Processing Record 14 of Set 4 | saint george
# Processing Record 15 of Set 4 | zhigansk
# Processing Record 16 of Set 4 | jackson
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | salinopolis
# Processing Record 19 of Set 4 | khash
# Processing Record 20 of Set 4 | barrow
# Processing Record 21 of Set 4 | lichuan
# Processing Record 22 of Set 4 | burica
# City not found. Skipping...
# Processing Record 23 of Set 4 | channel-port aux basques
# Processing Record 24 of Set 4 | tigil
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | katangli
# Processing Record 27 of Set 4 | morant bay
# Processing Record 28 of Set 4 | terrace bay
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | tadine
# Processing Record 31 of Set 4 | olafsvik
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | hanzhong
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | flin flon
# Processing Record 38 of Set 4 | yoshida
# Processing Record 39 of Set 4 | shangqiu
# Processing Record 40 of Set 4 | intipuca
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | flinders
# Processing Record 45 of Set 4 | mayo
# Processing Record 46 of Set 4 | srednekolymsk
# Processing Record 47 of Set 4 | quatre cocos
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | vardo
# Processing Record 50 of Set 4 | tessalit
# Processing Record 1 of Set 5 | tezu
# Processing Record 2 of Set 5 | princeton
# Processing Record 3 of Set 5 | new norfolk
# Processing Record 4 of Set 5 | fort nelson
# Processing Record 5 of Set 5 | tuatapere
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | aban
# Processing Record 8 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 5 | ibra
# Processing Record 10 of Set 5 | orapa
# Processing Record 11 of Set 5 | monrovia
# Processing Record 12 of Set 5 | hami
# Processing Record 13 of Set 5 | puerto penasco
# Processing Record 14 of Set 5 | kalmunai
# Processing Record 15 of Set 5 | kachug
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | lashio
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | severodvinsk
# Processing Record 20 of Set 5 | nancha
# Processing Record 21 of Set 5 | laguna
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | lagoa
# Processing Record 24 of Set 5 | fairbanks
# Processing Record 25 of Set 5 | dunedin
# Processing Record 26 of Set 5 | balakovo
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | karpogory
# Processing Record 29 of Set 5 | dwarka
# Processing Record 30 of Set 5 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 5 | bontang
# Processing Record 32 of Set 5 | houma
# Processing Record 33 of Set 5 | faya
# Processing Record 34 of Set 5 | mount abu
# Processing Record 35 of Set 5 | quibdo
# Processing Record 36 of Set 5 | santa cruz
# Processing Record 37 of Set 5 | karasburg
# Processing Record 38 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 5 | mahon
# Processing Record 40 of Set 5 | portel
# Processing Record 41 of Set 5 | yumen
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | guinticgan
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | akyab
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | itarema
# Processing Record 48 of Set 5 | bastia
# Processing Record 49 of Set 5 | codrington
# Processing Record 50 of Set 5 | college
# Processing Record 1 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 2 of Set 6 | beauchamps
# Processing Record 3 of Set 6 | kentau
# Processing Record 4 of Set 6 | tocopilla
# Processing Record 5 of Set 6 | east london
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 9 of Set 6 | guelengdeng
# City not found. Skipping...
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | isla mujeres
# Processing Record 12 of Set 6 | nautla
# Processing Record 13 of Set 6 | agadez
# Processing Record 14 of Set 6 | pryazha
# Processing Record 15 of Set 6 | campbell river
# Processing Record 16 of Set 6 | puerto escondido
# Processing Record 17 of Set 6 | verkhnevilyuysk
# Processing Record 18 of Set 6 | prince rupert
# Processing Record 19 of Set 6 | zwedru
# Processing Record 20 of Set 6 | mahebourg
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | taft
# Processing Record 23 of Set 6 | shahreza
# Processing Record 24 of Set 6 | rocha
# Processing Record 25 of Set 6 | dikson
# Processing Record 26 of Set 6 | litovko
# Processing Record 27 of Set 6 | makakilo city
# Processing Record 28 of Set 6 | birakan
# Processing Record 29 of Set 6 | manakara
# Processing Record 30 of Set 6 | muravlenko
# Processing Record 31 of Set 6 | porto novo
# Processing Record 32 of Set 6 | menongue
# Processing Record 33 of Set 6 | lat yao
# Processing Record 34 of Set 6 | hudson bay
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | robertsport
# Processing Record 38 of Set 6 | nakuru
# Processing Record 39 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 6 | aksarka
# Processing Record 41 of Set 6 | khuzdar
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | airai
# Processing Record 44 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 6 | kavaratti
# Processing Record 46 of Set 6 | kulhudhuffushi
# Processing Record 47 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 6 | paka
# Processing Record 49 of Set 6 | birin
# Processing Record 50 of Set 6 | arraial do cabo
# Processing Record 1 of Set 7 | pitimbu
# Processing Record 2 of Set 7 | bud
# Processing Record 3 of Set 7 | westport
# Processing Record 4 of Set 7 | taoudenni
# Processing Record 5 of Set 7 | clyde river
# Processing Record 6 of Set 7 | nyurba
# Processing Record 7 of Set 7 | kokopo
# Processing Record 8 of Set 7 | limbang
# Processing Record 9 of Set 7 | sisimiut
# Processing Record 10 of Set 7 | hamilton
# Processing Record 11 of Set 7 | waddan
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | namatanai
# Processing Record 14 of Set 7 | villefontaine
# Processing Record 15 of Set 7 | kosh-agach
# Processing Record 16 of Set 7 | komsomolskiy
# Processing Record 17 of Set 7 | los chiles
# Processing Record 18 of Set 7 | borovoy
# Processing Record 19 of Set 7 | georgetown
# Processing Record 20 of Set 7 | satana
# Processing Record 21 of Set 7 | narsaq
# Processing Record 22 of Set 7 | ribeira grande
# Processing Record 23 of Set 7 | iskateley
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | bandar-e lengeh
# Processing Record 26 of Set 7 | bam
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | birao
# Processing Record 29 of Set 7 | shingu
# Processing Record 30 of Set 7 | palu
# Processing Record 31 of Set 7 | kaabong
# Processing Record 32 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 7 | honningsvag
# Processing Record 34 of Set 7 | moyale
# Processing Record 35 of Set 7 | zhirnovsk
# Processing Record 36 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 7 | zeya
# Processing Record 39 of Set 7 | chokurdakh
# Processing Record 40 of Set 7 | sioux lookout
# Processing Record 41 of Set 7 | pietarsaari
# Processing Record 42 of Set 7 | matadi
# Processing Record 43 of Set 7 | marystown
# Processing Record 44 of Set 7 | ipanema
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | manavgat
# Processing Record 47 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 7 | chilliwack
# Processing Record 49 of Set 7 | oranjemund
# Processing Record 50 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 8 | kapan
# Processing Record 2 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 8 | general pico
# Processing Record 4 of Set 8 | cidreira
# Processing Record 5 of Set 8 | funtua
# Processing Record 6 of Set 8 | erenhot
# Processing Record 7 of Set 8 | great falls
# Processing Record 8 of Set 8 | loandjili
# Processing Record 9 of Set 8 | valleyview
# Processing Record 10 of Set 8 | nagato
# Processing Record 11 of Set 8 | puerto varas
# Processing Record 12 of Set 8 | huarmey
# Processing Record 13 of Set 8 | atlantis
# Processing Record 14 of Set 8 | sibolga
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | joshimath
# Processing Record 17 of Set 8 | iralaya
# Processing Record 18 of Set 8 | champerico
# Processing Record 19 of Set 8 | inhambane
# Processing Record 20 of Set 8 | nemuro
# Processing Record 21 of Set 8 | chimoio
# Processing Record 22 of Set 8 | arapongas
# Processing Record 23 of Set 8 | mizan teferi
# Processing Record 24 of Set 8 | hervey bay
# Processing Record 25 of Set 8 | kungurtug
# Processing Record 26 of Set 8 | newport
# Processing Record 27 of Set 8 | bugama
# Processing Record 28 of Set 8 | gizo
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | miri
# Processing Record 31 of Set 8 | hambantota
# Processing Record 32 of Set 8 | cururupu
# Processing Record 33 of Set 8 | lavrentiya
# Processing Record 34 of Set 8 | presidente epitacio
# Processing Record 35 of Set 8 | alice springs
# Processing Record 36 of Set 8 | tura
# Processing Record 37 of Set 8 | praia da vitoria
# Processing Record 38 of Set 8 | broome
# Processing Record 39 of Set 8 | meulaboh
# Processing Record 40 of Set 8 | auki
# Processing Record 41 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | matay
# Processing Record 44 of Set 8 | baruun-urt
# Processing Record 45 of Set 8 | aykhal
# Processing Record 46 of Set 8 | barabash
# Processing Record 47 of Set 8 | beringovskiy
# Processing Record 48 of Set 8 | nakamura
# Processing Record 49 of Set 8 | ghatanji
# Processing Record 50 of Set 8 | usva
# City not found. Skipping...
# Processing Record 1 of Set 9 | fare
# Processing Record 2 of Set 9 | lyubech
# Processing Record 3 of Set 9 | togur
# Processing Record 4 of Set 9 | zhetybay
# City not found. Skipping...
# Processing Record 5 of Set 9 | belogorsk
# Processing Record 6 of Set 9 | axim
# Processing Record 7 of Set 9 | novyy urengoy
# Processing Record 8 of Set 9 | jinxiang
# Processing Record 9 of Set 9 | samarai
# Processing Record 10 of Set 9 | emba
# Processing Record 11 of Set 9 | calama
# Processing Record 12 of Set 9 | vao
# Processing Record 13 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 9 | kindersley
# Processing Record 16 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | otaki
# Processing Record 20 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 22 of Set 9 | opuwo
# Processing Record 23 of Set 9 | rimouski
# Processing Record 24 of Set 9 | key largo
# Processing Record 25 of Set 9 | angoche
# Processing Record 26 of Set 9 | mangaratiba
# Processing Record 27 of Set 9 | ponta delgada
# Processing Record 28 of Set 9 | imeni zhelyabova
# Processing Record 29 of Set 9 | vilhena
# Processing Record 30 of Set 9 | hovd
# Processing Record 31 of Set 9 | rawson
# Processing Record 32 of Set 9 | along
# Processing Record 33 of Set 9 | sovetskiy
# Processing Record 34 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 9 | davila
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | porto santo
# Processing Record 38 of Set 9 | general roca
# Processing Record 39 of Set 9 | telenesti
# Processing Record 40 of Set 9 | buala
# Processing Record 41 of Set 9 | sena madureira
# Processing Record 42 of Set 9 | yar-sale
# Processing Record 43 of Set 9 | kollam
# Processing Record 44 of Set 9 | sita road
# Processing Record 45 of Set 9 | thinadhoo
# Processing Record 46 of Set 9 | yining
# Processing Record 47 of Set 9 | mitu
# Processing Record 48 of Set 9 | faanui
# Processing Record 49 of Set 9 | kill
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | dingle
# Processing Record 2 of Set 10 | telafas
# Processing Record 3 of Set 10 | karonga
# Processing Record 4 of Set 10 | moose factory
# Processing Record 5 of Set 10 | henties bay
# Processing Record 6 of Set 10 | starozhilovo
# Processing Record 7 of Set 10 | kavieng
# Processing Record 8 of Set 10 | ystad
# Processing Record 9 of Set 10 | bardiyah
# Processing Record 10 of Set 10 | spassk
# Processing Record 11 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 10 | lawrenceville
# Processing Record 13 of Set 10 | damghan
# Processing Record 14 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 10 | sarangani
# Processing Record 16 of Set 10 | ruthin
# Processing Record 17 of Set 10 | nicoya
# Processing Record 18 of Set 10 | riberalta
# Processing Record 19 of Set 10 | andreapol
# Processing Record 20 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 10 | victor harbor
# Processing Record 23 of Set 10 | mutis
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | katsuura
# Processing Record 26 of Set 10 | sapiranga
# Processing Record 27 of Set 10 | romitan
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | ambon
# Processing Record 30 of Set 10 | saluzzo
# Processing Record 31 of Set 10 | nizhniy tsasuchey
# Processing Record 32 of Set 10 | kuytun
# Processing Record 33 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 10 | mandan
# Processing Record 35 of Set 10 | pankrushikha
# Processing Record 36 of Set 10 | alenquer
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 10 | dahuk
# Processing Record 40 of Set 10 | aguililla
# Processing Record 41 of Set 10 | nieuw nickerie
# Processing Record 42 of Set 10 | brae
# Processing Record 43 of Set 10 | aqtobe
# Processing Record 44 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 10 | tautira
# Processing Record 46 of Set 10 | mundo nuevo
# Processing Record 47 of Set 10 | malakal
# Processing Record 48 of Set 10 | springbok
# Processing Record 49 of Set 10 | puerto maldonado
# Processing Record 50 of Set 10 | basco
# Processing Record 1 of Set 11 | mamou
# Processing Record 2 of Set 11 | benguela
# Processing Record 3 of Set 11 | qurayyat
# Processing Record 4 of Set 11 | malindi
# Processing Record 5 of Set 11 | sydney
# Processing Record 6 of Set 11 | guerrero negro
# Processing Record 7 of Set 11 | biak
# Processing Record 8 of Set 11 | urbano santos
# Processing Record 9 of Set 11 | belorechensk
# Processing Record 10 of Set 11 | severo-kurilsk
# Processing Record 11 of Set 11 | sechura
# Processing Record 12 of Set 11 | souillac
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | redlands
# Processing Record 15 of Set 11 | otjiwarongo
# Processing Record 16 of Set 11 | klaksvik
# Processing Record 17 of Set 11 | zyryanka
# Processing Record 18 of Set 11 | ariquemes
# Processing Record 19 of Set 11 | sakakah
# Processing Record 20 of Set 11 | price
# Processing Record 21 of Set 11 | burhaniye
# Processing Record 22 of Set 11 | bafra
# Processing Record 23 of Set 11 | zile
# Processing Record 24 of Set 11 | antalaha
# Processing Record 25 of Set 11 | irbil
# Processing Record 26 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 11 | goderich
# Processing Record 28 of Set 11 | cockburn town
# Processing Record 29 of Set 11 | horn lake
# Processing Record 30 of Set 11 | larsnes
# Processing Record 31 of Set 11 | witu
# Processing Record 32 of Set 11 | touros
# Processing Record 33 of Set 11 | ust-tsilma
# Processing Record 34 of Set 11 | kamaishi
# Processing Record 35 of Set 11 | beloha
# Processing Record 36 of Set 11 | acapulco
# Processing Record 37 of Set 11 | mieres
# Processing Record 38 of Set 11 | haines junction
# Processing Record 39 of Set 11 | chiredzi
# Processing Record 40 of Set 11 | moroni
# Processing Record 41 of Set 11 | nouadhibou
# Processing Record 42 of Set 11 | edson
# Processing Record 43 of Set 11 | gaomi
# Processing Record 44 of Set 11 | sendafa
# Processing Record 45 of Set 11 | pafos
# Processing Record 46 of Set 11 | hammerfest
# Processing Record 47 of Set 11 | letterkenny
# Processing Record 48 of Set 11 | goedereede
# Processing Record 49 of Set 11 | severo-yeniseyskiy
# Processing Record 50 of Set 11 | colares
# Processing Record 1 of Set 12 | teruel
# Processing Record 2 of Set 12 | adre
# Processing Record 3 of Set 12 | porto de moz
# Processing Record 4 of Set 12 | kazerun
# Processing Record 5 of Set 12 | medina del campo
# Processing Record 6 of Set 12 | anadyr
# Processing Record 7 of Set 12 | mithi
# Processing Record 8 of Set 12 | raudeberg
# Processing Record 9 of Set 12 | belle glade
# Processing Record 10 of Set 12 | maniitsoq
# Processing Record 11 of Set 12 | bikin
# Processing Record 12 of Set 12 | jawhar
# Processing Record 13 of Set 12 | tayga
# Processing Record 14 of Set 12 | phangnga
# Processing Record 15 of Set 12 | shitkino
# Processing Record 16 of Set 12 | anyang
# Processing Record 17 of Set 12 | bathsheba
# Processing Record 18 of Set 12 | maceio
# Processing Record 19 of Set 12 | gat
# Processing Record 20 of Set 12 | lahij
# Processing Record 21 of Set 12 | santo antonio do sudoeste
# Processing Record 22 of Set 12 | portobelo
# Processing Record 23 of Set 12 | makaryev
# Processing Record 24 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 25 of Set 12 | jinji
# Processing Record 26 of Set 12 | khani
# Processing Record 27 of Set 12 | nioro
# Processing Record 28 of Set 12 | bougouni
# Processing Record 29 of Set 12 | chapais
# Processing Record 30 of Set 12 | vila do maio
# Processing Record 31 of Set 12 | kathmandu
# Processing Record 32 of Set 12 | bosaso
# Processing Record 33 of Set 12 | palauig
# Processing Record 34 of Set 12 | lasa
# Processing Record 35 of Set 12 | cayenne
# Processing Record 36 of Set 12 | jalingo
# Processing Record 37 of Set 12 | quesnel
# Processing Record 38 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 12 | santa vitoria do palmar
# Processing Record 40 of Set 12 | bon air
# Processing Record 41 of Set 12 | sorland
# Processing Record 42 of Set 12 | ajdabiya
# Processing Record 43 of Set 12 | uyuni
# Processing Record 44 of Set 12 | krasnoborsk
# Processing Record 45 of Set 12 | abu dhabi
# Processing Record 46 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 12 | stromness
# Processing Record 48 of Set 12 | halifax
# Processing Record 49 of Set 12 | kembe
# Processing Record 50 of Set 12 | takapau
# Processing Record 1 of Set 13 | port keats
# Processing Record 2 of Set 13 | mehamn
# Processing Record 3 of Set 13 | englewood
# Processing Record 4 of Set 13 | auxerre
# Processing Record 5 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 13 | ostrovnoy
# Processing Record 7 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 8 of Set 13 | san martin jilotepeque
# Processing Record 9 of Set 13 | kanlagay
# Processing Record 10 of Set 13 | pacific grove
# Processing Record 11 of Set 13 | marawi
# Processing Record 12 of Set 13 | aklavik
# Processing Record 13 of Set 13 | fontanka
# Processing Record 14 of Set 13 | kudahuvadhoo
# Processing Record 15 of Set 13 | canalete
# Processing Record 16 of Set 13 | korla
# Processing Record 17 of Set 13 | lewistown
# Processing Record 18 of Set 13 | chibuto
# Processing Record 19 of Set 13 | preston
# Processing Record 20 of Set 13 | tabas
# Processing Record 21 of Set 13 | millbrook
# Processing Record 22 of Set 13 | tha chang
# Processing Record 23 of Set 13 | ambilobe
# Processing Record 24 of Set 13 | lichinga
# Processing Record 25 of Set 13 | san cristobal
# Processing Record 26 of Set 13 | mangrol
# Processing Record 27 of Set 13 | tongchuan
# Processing Record 28 of Set 13 | saint-michel-des-saints
# Processing Record 29 of Set 13 | oussouye
# Processing Record 30 of Set 13 | barranca
# Processing Record 31 of Set 13 | mutare
# Processing Record 32 of Set 13 | charters towers
# Processing Record 33 of Set 13 | nurota
# Processing Record 34 of Set 13 | payo
# Processing Record 35 of Set 13 | atar
# Processing Record 36 of Set 13 | vestmannaeyjar
# Processing Record 37 of Set 13 | jishou
# Processing Record 38 of Set 13 | novopavlovka
# Processing Record 39 of Set 13 | san angelo
# Processing Record 40 of Set 13 | izhma
# Processing Record 41 of Set 13 | ransang
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | massakory
# Processing Record 44 of Set 13 | yaan
# Processing Record 45 of Set 13 | katherine
# Processing Record 46 of Set 13 | hobyo
# Processing Record 47 of Set 13 | comrie
# Processing Record 48 of Set 13 | kinsale
# Processing Record 49 of Set 13 | carballo
# Processing Record 50 of Set 13 | rodrigues alves
# Processing Record 1 of Set 14 | gurupa
# Processing Record 2 of Set 14 | rio gallegos
# Processing Record 3 of Set 14 | cap malheureux
# Processing Record 4 of Set 14 | anito
# Processing Record 5 of Set 14 | broken hill
# Processing Record 6 of Set 14 | uchiza
# Processing Record 7 of Set 14 | pouso alegre
# Processing Record 8 of Set 14 | maragogi
# Processing Record 9 of Set 14 | alamogordo
# Processing Record 10 of Set 14 | progreso
# Processing Record 11 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 14 | saint anthony
# Processing Record 13 of Set 14 | inirida
# Processing Record 14 of Set 14 | half moon bay
# Processing Record 15 of Set 14 | voyinka
# Processing Record 16 of Set 14 | phan thiet
# Processing Record 17 of Set 14 | rabo de peixe
# Processing Record 18 of Set 14 | kununurra
# Processing Record 19 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 20 of Set 14 | jadu
# Processing Record 21 of Set 14 | cuencame
# Processing Record 22 of Set 14 | marsabit
# Processing Record 23 of Set 14 | la trinitaria
# Processing Record 24 of Set 14 | saint-gabriel
# Processing Record 25 of Set 14 | kobayashi
# Processing Record 26 of Set 14 | buchanan
# Processing Record 27 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 14 | kyzyl-suu
# Processing Record 29 of Set 14 | bowen
# Processing Record 30 of Set 14 | port pirie
# Processing Record 31 of Set 14 | berdigestyakh
# Processing Record 32 of Set 14 | eureka
# Processing Record 33 of Set 14 | lusambo
# Processing Record 34 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 14 | sao felix do xingu
# Processing Record 36 of Set 14 | tamiahua
# Processing Record 37 of Set 14 | millville
# Processing Record 38 of Set 14 | chone
# Processing Record 39 of Set 14 | kloulklubed
# Processing Record 40 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 14 | yinchuan
# Processing Record 42 of Set 14 | oron
# Processing Record 43 of Set 14 | boende
# Processing Record 44 of Set 14 | greenville
# Processing Record 45 of Set 14 | mpika
# Processing Record 46 of Set 14 | dosso
# Processing Record 47 of Set 14 | olga
# Processing Record 48 of Set 14 | jambi
# Processing Record 49 of Set 14 | beira
# Processing Record 50 of Set 14 | maiduguri
# Processing Record 1 of Set 15 | vanimo
# Processing Record 2 of Set 15 | epe
# Processing Record 3 of Set 15 | valparaiso
# Processing Record 4 of Set 15 | saint andrews
# Processing Record 5 of Set 15 | fallon
# Processing Record 6 of Set 15 | ancud
# Processing Record 7 of Set 15 | guarda
# Processing Record 8 of Set 15 | solnechnyy
# Processing Record 9 of Set 15 | maningrida
# Processing Record 10 of Set 15 | sangmelima
# Processing Record 11 of Set 15 | svetlogorsk
# Processing Record 12 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 15 | kijang
# Processing Record 14 of Set 15 | raga
# Processing Record 15 of Set 15 | boyabat
# Processing Record 16 of Set 15 | vila
# Processing Record 17 of Set 15 | la ronge
# Processing Record 18 of Set 15 | skelleftea
# Processing Record 19 of Set 15 | moindou
# Processing Record 20 of Set 15 | kemijarvi
# Processing Record 21 of Set 15 | muisne
# Processing Record 22 of Set 15 | abu samrah
# Processing Record 23 of Set 15 | antofagasta
# Processing Record 24 of Set 15 | vaitape
# Processing Record 25 of Set 15 | puerto rico
# Processing Record 26 of Set 15 | los llanos de aridane
# Processing Record 27 of Set 15 | matara
# Processing Record 28 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 15 | mushie
# Processing Record 30 of Set 15 | pokrovsk
# Processing Record 31 of Set 15 | mao
# Processing Record 32 of Set 15 | ahipara
# Processing Record 33 of Set 15 | surt
# Processing Record 34 of Set 15 | omsukchan
# Processing Record 35 of Set 15 | artigas
# Processing Record 36 of Set 15 | dvorichna
# Processing Record 37 of Set 15 | port blair
# Processing Record 38 of Set 15 | burgeo
# Processing Record 39 of Set 15 | igrim
# Processing Record 40 of Set 15 | kirensk
# Processing Record 41 of Set 15 | rizhao
# Processing Record 42 of Set 15 | stokmarknes
# Processing Record 43 of Set 15 | ust-tarka
# Processing Record 44 of Set 15 | kiruna
# Processing Record 45 of Set 15 | sembe
# Processing Record 46 of Set 15 | verkhnyaya toyma
# Processing Record 47 of Set 15 | mirabad
# Processing Record 48 of Set 15 | qasigiannguit
# Processing Record 49 of Set 15 | amlame
# Processing Record 50 of Set 15 | puli
# Processing Record 1 of Set 16 | lagos
# Processing Record 2 of Set 16 | troitskoye
# Processing Record 3 of Set 16 | chicama
# Processing Record 4 of Set 16 | kinango
# Processing Record 5 of Set 16 | semey
# Processing Record 6 of Set 16 | doha
# Processing Record 7 of Set 16 | churapcha
# Processing Record 8 of Set 16 | mezhdurechensk
# Processing Record 9 of Set 16 | owensboro
# Processing Record 10 of Set 16 | roma
# Processing Record 11 of Set 16 | acoyapa
# Processing Record 12 of Set 16 | mazara del vallo
# Processing Record 13 of Set 16 | komyshnya
# Processing Record 14 of Set 16 | jedburgh
# Processing Record 15 of Set 16 | bilibino
# Processing Record 16 of Set 16 | sansare
# Processing Record 17 of Set 16 | smithers
# Processing Record 18 of Set 16 | awbari
# Processing Record 19 of Set 16 | pestovo
# Processing Record 20 of Set 16 | douglas
# Processing Record 21 of Set 16 | namanga
# Processing Record 22 of Set 16 | culpeper
# Processing Record 23 of Set 16 | dorado
# Processing Record 24 of Set 16 | gamba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 710

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hithadhoo      MV  -0.6000   73.0833     79.95        76          98
# 1        Sinnamary      GF   5.3833  -52.9500     79.43        83          84
# 2         Thompson      CA  55.7435  -97.8558     69.96        68          75
# 3           Hobart      AU -42.8794  147.3294     53.26        72          40
# 4            Wamba      NG   8.9333    8.6000     70.59        98          89
# 5        Egvekinot      RU  66.3167 -179.1667     48.97        52          77
# 6            Essen      DE  51.4500    7.0167     59.65        86          52
# 7            Kapaa      US  22.0752 -159.3190     84.18        68          47
# 8           Torbay      CA  47.6666  -52.7314     55.27        92          90
# 9  Plettenberg Bay      ZA -34.0527   23.3716     56.61        60         100
#
#    Wind Speed          Current Description
# 0        4.59              overcast clouds
# 1       12.01                broken clouds
# 2        8.05                broken clouds
# 3        1.99             scattered clouds
# 4        3.00                   light rain
# 5       14.07                broken clouds
# 6        1.99                broken clouds
# 7        4.00             scattered clouds
# 8       14.97  light intensity shower rain
# 9        8.34              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
